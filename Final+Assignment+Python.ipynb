# %% [markdown]
# # Global Value Chains: NAFTA
#
#
#
# |Name|examnr.|
# |----|-------|
# |Jesse Bijnen|1258985|
# |Adelina Sharipova|2018931|

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Method

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


file1 = 'WIOT_Cleaned_1995.xlsx'
file2 = 'WIOT_Cleaned_2011.xlsx'
WIOT1995 = pd.ExcelFile(file1)
pd.to_numeric(WIOT1995, errors='coerce')
WIOT2011 = pd.ExcelFile(file2)
pd.to_numeric(WIOT2011, errors='coerce')

IOT1995 = WIOT1995.parse('US-MEX')
IOT1995
# Out:
#                                                  Food, Beverages and Tobacco  \
# NaN                                          NaN                         USA
# Food, Beverages and Tobacco                  MEX                     69.0721
# Textiles and Textile Products                MEX                     1.42418
# Leather, Leather and Footwear                MEX                    0.416352
# Wood and Products of Wood and Cork           MEX                    0.901305
# Pulp, Paper, Paper , Printing and Publishing MEX                     42.2552
# Coke, Refined Petroleum and Nuclear Fuel     MEX                     1.88338
# Chemicals and Chemical Products              MEX                     24.1464
# Rubber and Plastics                          MEX                     51.4138
# Other Non-Metallic Mineral                   MEX                     28.5625
# Basic Metals and Fabricated Metal            MEX                     74.9843
# ...

# %%
dfUSMEX2011 = WIOT2011.parse('US-MEX')

dfUSMEX2011.columns = df.dfUSMEX2011[0]
df = df[1:]

df.to_xlsx(path, index= False)
dfUSMEX2011
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-316664b65c76> in <module>()
#       1 dfUSMEX2011 = WIOT2011.parse('US-MEX')
#       2
# ----> 3 dfUSMEX2011.columns = df.dfUSMEX2011[0]
#       4 df = df[1:]
#       5
#
# AttributeError: 'ExcelFile' object has no attribute 'dfUSMEX2011'

# %%
from openpyxl import load_workbook
wb = load_workbook('WIOT_Cleaned_1995.xlsx')
print(wb.get_sheet_names())
# Out:
# ['US-MEX', 'US-CAN', 'MEX-CAN', 'MEX-US', 'CAN-US', 'CAN-MEX', 'TOTAL']

# %%
wb.active
# Out:
# <Worksheet "US-MEX">
